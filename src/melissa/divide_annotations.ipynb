# %%
import pandas as pd

# %%
# !ls ../../data
datafile = '../../data/deduplicated_tweets.2023-03-26_14.08.48.636120.tsv'
df = pd.read_csv(datafile, sep='\t')
df.head()
# Out:
# #chrisrocklive_project_tweets.2023-03-09_17.16.18.676751.json
# #chrisrocklive_project_tweets.2023-03-09_17.16.18.676751.tsv
# #tyrenichols_project_tweets.2023-03-09_19.25.43.435891.json
# #tyrenichols_project_tweets.2023-03-09_19.25.43.435891.tsv
# chatgpt_project_tweets.2023-03-09_19.12.39.616553.json
# chatgpt_project_tweets.2023-03-09_19.12.39.616553.tsv
# deduplicated_tweets.2023-03-26_14.08.48.636120.tsv
# maga_project_tweets.2023-03-08_22.25.11.437694.json
# maga_project_tweets.2023-03-08_22.25.11.437694.tsv
# obama_project_tweets.2023-03-08_22.36.15.226664.json
# obama_project_tweets.2023-03-08_22.36.15.226664.tsv
# project_data.2023-03-11_13.11.55.783862.csv
# project_data.2023-03-11_13.11.55.783862.json
# russia_project_tweets.2023-03-08_22.51.51.710826.json
# russia_project_tweets.2023-03-08_22.51.51.710826.tsv
# scraped_data
# statehood_project_tweets.2023-03-09_17.12.00.547177.json
# statehood_project_tweets.2023-03-09_17.12.00.547177.tsv
# ...

# %%
annotation_df = df.sample(n=300)
annotation_df['our_label'] = ""
display(annotation_df.head())
mel_df = annotation_df[:100]
mel_df.shape

anu_df = annotation_df[100:200]
sarik_df = annotation_df[200:]
print(mel_df.shape, anu_df.shape, sarik_df.shape)

mel_df.to_csv('../../data/mel_annotations.tsv')
anu_df.to_csv('../../data/anu_annotations.tsv')
sarik_df.to_csv('../../data/sarik_annotations.tsv')
# Out:
#        Unnamed: 0      conversation_id lang reply_settings  \
# 13581       17871  1633665111406542848   en       everyone
# 13249       17539  1633666519245750272   en       everyone
# 28682       32972  1633876284940877824   en       everyone
# 1203         1203  1633277949234364416   en       everyone
# 22163       26453  1633668541122592768   en       everyone
#
#                       created_at  \
# 13581  2023-03-09 03:04:49+00:00
# 13249  2023-03-09 03:10:24+00:00
# 28682  2023-03-09 17:03:56+00:00
# 1203   2023-03-08 01:26:22+00:00
# 22163  2023-03-09 03:18:26+00:00
#
#                                               clean_text  \
# 13581  rt tomfitton obama knew clinton knew biden kne...
# 13249  cant even threaten friend game without watchli...
# 28682  trump impeached call gop house brought article...
# 1203   rt sagesurge marlon wayans roasting chris rock...
# 22163  rt visegrad time west send patriot missile def...
#
# ...

# %%
ls ../../data/
# Out:
# #chrisrocklive_project_tweets.2023-03-09_17.16.18.676751.json
# #chrisrocklive_project_tweets.2023-03-09_17.16.18.676751.tsv
# #tyrenichols_project_tweets.2023-03-09_19.25.43.435891.json
# #tyrenichols_project_tweets.2023-03-09_19.25.43.435891.tsv
# anu_annotations.tsv
# chatgpt_project_tweets.2023-03-09_19.12.39.616553.json
# chatgpt_project_tweets.2023-03-09_19.12.39.616553.tsv
# deduplicated_tweets.2023-03-26_14.08.48.636120.tsv
# maga_project_tweets.2023-03-08_22.25.11.437694.json
# maga_project_tweets.2023-03-08_22.25.11.437694.tsv
# mel_annotations.tsv
# obama_project_tweets.2023-03-08_22.36.15.226664.json
# obama_project_tweets.2023-03-08_22.36.15.226664.tsv
# project_data.2023-03-11_13.11.55.783862.csv
# project_data.2023-03-11_13.11.55.783862.json
# russia_project_tweets.2023-03-08_22.51.51.710826.json
# russia_project_tweets.2023-03-08_22.51.51.710826.tsv
# sarik_annotations.tsv
# scraped_data/
# statehood_project_tweets.2023-03-09_17.12.00.547177.json
# ...

# %% [markdown]
# # Melissa Annotations

# %%
# mel_df.to_csv('../../data/mel_annotations.csv')  # I made a .csv that was easier to open in excel
# Did my annotations there.
# Convert back to .tsv format to match the others.

mel_annotated_df = pd.read_csv('../../data/mel_annotations.csv')
mel_annotated_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  conversation_id lang reply_settings  \
# 0       13581         17871     1.633670e+18   en       everyone
# 1       13249         17539     1.633670e+18   en       everyone
# 2       28682         32972     1.633880e+18   en       everyone
# 3        1203          1203     1.633280e+18   en       everyone
# 4       22163         26453     1.633670e+18   en       everyone
#
#                   created_at  \
# 0  2023-03-09 03:04:49+00:00
# 1  2023-03-09 03:10:24+00:00
# 2  2023-03-09 17:03:56+00:00
# 3  2023-03-08 01:26:22+00:00
# 4  2023-03-09 03:18:26+00:00
#
#                                           clean_text  \
# 0  rt tomfitton obama knew clinton knew biden kne...
# 1  cant even threaten friend game without watchli...
# 2  trump impeached call gop house brought article...
# 3  rt sagesurge marlon wayans roasting chris rock...
# 4  rt visegrad time west send patriot missile def...
#
# ...

# %%
mel_annotated_df['our_label'].value_counts()
# Out:
# neutral     57
# negative    34
# positive     9
# Name: our_label, dtype: int64

# %%
mel_annotated_df.to_csv('../../data/mel_annotations.tsv', sep='\t')
